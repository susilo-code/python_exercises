# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.4'

# %%
df = pd.read_csv("D:/python/COVID19_line_list_data.csv")
df.head(3)
# Out:
#    id  case_in_country reporting date  Unnamed: 3  \
# 0   1              NaN      1/20/2020         NaN
# 1   2              NaN      1/20/2020         NaN
# 2   3              NaN      1/21/2020         NaN
#
#                                              summary             location  \
# 0  First confirmed imported COVID-19 pneumonia pa...  Shenzhen, Guangdong
# 1  First confirmed imported COVID-19 pneumonia pa...             Shanghai
# 2  First confirmed imported cases in Zhejiang: pa...             Zhejiang
#
#   country  gender   age symptom_onset  ...  recovered symptom  \
# 0   China    male  66.0      01/03/20  ...          0     NaN
# 1   China  female  56.0     1/15/2020  ...          0     NaN
# 2   China    male  46.0      01/04/20  ...          0     NaN
#
#                                               source  \
# 0               Shenzhen Municipal Health Commission
# 1  Official Weibo of Shanghai Municipal Health Co...
# ...

# %%
df.tail()
# Out:
#         id  case_in_country reporting date  Unnamed: 3  \
# 1080  1081              2.0      2/25/2020         NaN
# 1081  1082              1.0      2/24/2020         NaN
# 1082  1083              1.0      2/26/2020         NaN
# 1083  1084              1.0      2/25/2020         NaN
# 1084  1085              1.0      2/25/2020         NaN
#
#                                                 summary     location  \
# 1080  new COVID-19 patient confirmed in Austria: 24,...    Innsbruck
# 1081  new COVID-19 patient confirmed in Afghanistan:...  Afghanistan
# 1082  new COVID-19 patient confirmed in Algeria: mal...      Algeria
# 1083  new COVID-19 patient confirmed in Croatia: mal...      Croatia
# 1084  new COVID-19 patient confirmed in Switzerland:...         Bern
#
#           country gender   age symptom_onset  ...  recovered symptom  \
# 1080      Austria    NaN  24.0           NaN  ...          0     NaN
# 1081  Afghanistan    NaN  35.0           NaN  ...          0     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     1085 non-null   int64
#  1   case_in_country        888 non-null    float64
#  2   reporting date         1084 non-null   object
#  3   Unnamed: 3             0 non-null      float64
#  4   summary                1080 non-null   object
#  5   location               1085 non-null   object
#  6   country                1085 non-null   object
#  7   gender                 902 non-null    object
#  8   age                    843 non-null    float64
#  9   symptom_onset          563 non-null    object
#  10  If_onset_approximated  560 non-null    float64
#  11  hosp_visit_date        507 non-null    object
#  12  exposure_start         128 non-null    object
#  13  exposure_end           341 non-null    object
# ...

# %%
df[['reporting date', 'location', 'country', 'gender', 'age', 'death', 'recovered']]
# Out:
#      reporting date             location      country  gender   age death  \
# 0         1/20/2020  Shenzhen, Guangdong        China    male  66.0     0
# 1         1/20/2020             Shanghai        China  female  56.0     0
# 2         1/21/2020             Zhejiang        China    male  46.0     0
# 3         1/21/2020              Tianjin        China  female  60.0     0
# 4         1/21/2020              Tianjin        China    male  58.0     0
# ...             ...                  ...          ...     ...   ...   ...
# 1080      2/25/2020            Innsbruck      Austria     NaN  24.0     0
# 1081      2/24/2020          Afghanistan  Afghanistan     NaN  35.0     0
# 1082      2/26/2020              Algeria      Algeria    male   NaN     0
# 1083      2/25/2020              Croatia      Croatia    male   NaN     0
# 1084      2/25/2020                 Bern  Switzerland    male  70.0     0
#
#      recovered
# 0            0
# 1            0
# 2            0
# ...

# %%
import pandas as pd
import numpy as np

def create_df(n):
    df = pd.DataFrame()
    df['position'] = np.random.choice(['GK', 'DEF', 'MID', 'ST'], size=n)
    df['height'] = np.round(np.random.normal(loc=180, scale=5, size=n))
    df['is_captain'] = np.random.choice(['YES', 'NO'], size=n)
    df['scoring_probability'] = np.random.uniform(low=0, high=1, size=n)
    df['minutes_played_last_season'] = np.random.randint(low=-3000, high=3000, size=n)
    return df

df = create_df(1000000)
df.head()
# Out:
#   position  height is_captain  scoring_probability  minutes_played_last_season
# 0      MID   181.0         NO             0.196537                        2116
# 1       ST   191.0        YES             0.734960                        -612
# 2      DEF   183.0        YES             0.142518                       -1022
# 3      DEF   185.0        YES             0.147887                        1707
# 4      MID   170.0        YES             0.490011                        2326

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   position                    1000000 non-null  object
#  1   height                      1000000 non-null  float64
#  2   is_captain                  1000000 non-null  object
#  3   scoring_probability         1000000 non-null  float64
#  4   minutes_played_last_season  1000000 non-null  int32
# dtypes: float64(2), int32(1), object(2)
# memory usage: 34.3+ MB

# %%
# Only keep the relevant columns
df = df[['position', 'height', 'is_captain', 'scoring_probability']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   position             1000000 non-null  object
#  1   height               1000000 non-null  float64
#  2   is_captain           1000000 non-null  object
#  3   scoring_probability  1000000 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 30.5+ MB

# %%
# Object to Category and Object to Boolean
df['position'] = df['position'].astype('category')
df['is_captain'] = df['is_captain'].map({'YES':True, 'NO':False})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   position             1000000 non-null  category
#  1   height               1000000 non-null  float64
#  2   is_captain           1000000 non-null  bool
#  3   scoring_probability  1000000 non-null  float64
# dtypes: bool(1), category(1), float64(2)
# memory usage: 17.2 MB

# %%
# Float64 to Uint8 and Float64 to Float32
df['height'] = df['height'].astype('uint8')
df['scoring_probability'] = df['scoring_probability'].astype('float32')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 4 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   position             1000000 non-null  category
#  1   height               1000000 non-null  uint8
#  2   is_captain           1000000 non-null  bool
#  3   scoring_probability  1000000 non-null  float32
# dtypes: bool(1), category(1), float32(1), uint8(1)
# memory usage: 6.7 MB

# %%
df.height.describe()
# Out:
# count    1000000.000000
# mean         179.994173
# std            5.012578
# min          156.000000
# 25%          177.000000
# 50%          180.000000
# 75%          183.000000
# max          205.000000
# Name: height, dtype: float64

# %%
df.position.value_counts()
# Out:
# DEF    250177
# GK     250107
# ST     250056
# MID    249660
# Name: position, dtype: int64
